# %% [markdown]
# ### Задание1

# %%
import pandas as pd
import numpy as np

# %%
a = pd.read_csv('C:/Users/akravchenko/Desktop/dataset/ratings.csv')

# %%
b = pd.read_csv('C:/Users/akravchenko/Desktop/dataset/movies.csv')

# %%
x = a[(a.rating == 5)].groupby('movieId').count().sort_values(by = ['rating'],ascending =[False])

# %%
x = x.merge(b, on='movieId')

# %%
x['no_of_5'] = x.rating

# %%
x[['movieId','title','no_of_5']]
# Out:
#       movieId                                              title  no_of_5
# 0         318                   Shawshank Redemption, The (1994)      153
# 1         296                                Pulp Fiction (1994)      123
# 2         356                                Forrest Gump (1994)      116
# 3        2571                                 Matrix, The (1999)      109
# 4         260          Star Wars: Episode IV - A New Hope (1977)      104
# 5         527                            Schindler's List (1993)       92
# 6         593                   Silence of the Lambs, The (1991)       92
# 7         858                              Godfather, The (1972)       88
# 8        2959                                  Fight Club (1999)       81
# 9         110                                  Braveheart (1995)       80
# 10       1196  Star Wars: Episode V - The Empire Strikes Back...       80
# 11         50                         Usual Suspects, The (1995)       71
# ...

# %% [markdown]
# ### Задание 2

# %%
x = pd.read_csv('C:/Users/Kanris/Desktop/data/power.csv')

# %%
x[x['country'].str.contains('lit|lat|est', case = False)]['country'].unique()
# Out:
# array(['Lithuania', 'Latvia', 'Estonia', 'State of Palestine',
#        'Timor-Leste'], dtype=object)

# %%
a = x[(((x.country =='Lithuania') | (x.country =='Latvia') | (x.country == 'Estonia')) & ((x.category == 4) | (x.category == 12) 
 | (x.category == 21)) & (x.quantity >= 0) & ((x.year >= 2005) & (x.year <= 2010) ))].groupby('country').sum()

# %%
a['quantity']
# Out:
# country
# Estonia       63440.0
# Latvia        54844.0
# Lithuania    122296.0
# Name: quantity, dtype: float64

# %%
a['quantity'].sum()
# Out:
# 240580.0

# %% [markdown]
# ### Задание 3

# %%
pd.read_html('https://fortrader.org/quotes')
# Out:
# [                               Type    Last  Chg.  Chg.%  Time
#  0  Нефть (BRENT) Курс нефти сегодня  61.610  0.90  1.480   NaN
#  1   Нефть (WTI) Цены на нефть (WTI)  56.610  0.49  0.870   NaN
#  2          Сахар котировки на сахар  12.630  0.00  0.000   NaN
#  3                   Газ Цена на газ   2.488  0.06  2.471   NaN,
#                                      Type          Last      Chg.     Chg.%  \
#  0                      ВТБ Акции ОАО ВТБ       0.04208  +0.00003   0.07134
#  1                 Газпром Акции газпрома     233.94000     -2.01  -0.85000
#  2                    Лукоил Акции Лукойл    5526.00000     +19.0   0.30000
#  3                Роснефть Акции Роснефти     422.35000     +4.20   1.00000
#  4               Сбербанк Акции Сбербанка     229.31000     -1.08  -0.47000
#  5   Сургутнефтегаз Акции Сургутнефтегаза      33.37000    -0.275  -0.81700
#  6              Норникель Акции Норникель   16164.00000      -174  -1.00000
# ...

# %%
x = pd.read_html('https://fortrader.org/quotes')

# %%
x[0].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 5 columns):
# Type     4 non-null object
# Last     4 non-null float64
# Chg.     4 non-null float64
# Chg.%    4 non-null float64
# Time     0 non-null float64
# dtypes: float64(4), object(1)
# memory usage: 240.0+ bytes
